# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("exams.csv")

# %%
dataset.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %%
dataset.values
# Out:
# array([['male', 'group A', 'high school', ..., 67, 67, 63],
#        ['female', 'group D', 'some high school', ..., 40, 59, 55],
#        ['male', 'group E', 'some college', ..., 59, 60, 50],
#        ...,
#        ['female', 'group C', 'some high school', ..., 32, 35, 41],
#        ['female', 'group C', 'some college', ..., 73, 74, 82],
#        ['male', 'group A', 'some college', ..., 65, 60, 62]], dtype=object)

# %%
dataset.lunch.unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
mask=dataset.isna()

# %%
dataset[mask]
# Out:
#     gender race/ethnicity parental level of education lunch  \
# 0      NaN            NaN                         NaN   NaN
# 1      NaN            NaN                         NaN   NaN
# 2      NaN            NaN                         NaN   NaN
# 3      NaN            NaN                         NaN   NaN
# 4      NaN            NaN                         NaN   NaN
# ..     ...            ...                         ...   ...
# 995    NaN            NaN                         NaN   NaN
# 996    NaN            NaN                         NaN   NaN
# 997    NaN            NaN                         NaN   NaN
# 998    NaN            NaN                         NaN   NaN
# 999    NaN            NaN                         NaN   NaN
#
#     test preparation course  math score  reading score  writing score
# 0                       NaN         NaN            NaN            NaN
# 1                       NaN         NaN            NaN            NaN
# ...

# %%
dataset.dropna()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
dataset=pd.read_csv('exams.csv', usecols=['gender','parental level of education'])

# %%
dataset
# Out:
#      gender parental level of education
# 0      male                 high school
# 1    female            some high school
# 2      male                some college
# 3      male                 high school
# 4      male          associate's degree
# ..      ...                         ...
# 995    male                 high school
# 996    male          associate's degree
# 997  female            some high school
# 998  female                some college
# 999    male                some college
#
# [1000 rows x 2 columns]

# %%
dataset.get('male',default=None)

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
dataset.shape
# Out:
# (1000, 2)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   parental level of education  1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
dataset.describe()
# Out:
#        gender parental level of education
# count    1000                        1000
# unique      2                           6
# top      male                some college
# freq      517                         222

# %%
dataset = pd.read_csv("exams.csv",index_col=['gender'])

# %%
dataset
# Out:
#        race/ethnicity parental level of education         lunch  \
# gender
# male          group A                 high school      standard
# female        group D            some high school  free/reduced
# male          group E                some college  free/reduced
# male          group B                 high school      standard
# male          group E          associate's degree      standard
# ...               ...                         ...           ...
# male          group C                 high school      standard
# male          group D          associate's degree  free/reduced
# female        group C            some high school  free/reduced
# female        group C                some college      standard
# male          group A                some college      standard
#
#        test preparation course  math score  reading score  writing score
# gender
# male                 completed          67             67             63
# ...

# %%
dataset.mean()
# Out:
# C:\Users\Meenal Patel\AppData\Local\Temp\ipykernel_15320\1799472221.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset.mean()
# math score       66.396
# reading score    69.002
# writing score    67.738
# dtype: float64

# %%
dataset.mean(axis=1)
# Out:
# C:\Users\Meenal Patel\AppData\Local\Temp\ipykernel_15320\2055894671.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset.mean(axis=1)
# gender
# male      65.666667
# female    51.333333
# male      56.333333
# male      74.333333
# male      73.000000
#             ...
# male      69.333333
# male      89.333333
# female    36.000000
# female    76.333333
# male      62.333333
# Length: 1000, dtype: float64

# %%
dataset['math score'].sum()
# Out:
# 66396

# %%
dataset['hindi marks']=np.random.randint(0,100,1000)

# %%
dataset
# Out:
#        race/ethnicity parental level of education         lunch  \
# gender
# male          group A                 high school      standard
# female        group D            some high school  free/reduced
# male          group E                some college  free/reduced
# male          group B                 high school      standard
# male          group E          associate's degree      standard
# ...               ...                         ...           ...
# male          group C                 high school      standard
# male          group D          associate's degree  free/reduced
# female        group C            some high school  free/reduced
# female        group C                some college      standard
# male          group A                some college      standard
#
#        test preparation course  math score  reading score  writing score  \
# gender
# male                 completed          67             67             63
# ...

# %%
dataset.sort_values('hindi marks')
# Out:
#        race/ethnicity parental level of education         lunch  \
# gender
# male          group D                some college  free/reduced
# male          group D            some high school  free/reduced
# male          group E           bachelor's degree  free/reduced
# female        group D          associate's degree  free/reduced
# female        group C          associate's degree      standard
# ...               ...                         ...           ...
# male          group D                some college      standard
# female        group D             master's degree      standard
# male          group E          associate's degree      standard
# female        group B                 high school      standard
# male          group B                some college      standard
#
#        test preparation course  math score  reading score  writing score  \
# gender
# male                 completed          62             68             71
# ...

# %%
dataset=dataset.sort_index()

# %%
dataset
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
dataset.inde
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 dataset = pd.read_csv("exams.csv",index='hindi marks')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
dataset
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
dataset = pd.read_csv("exams.csv",index_col=['math score'])
dataset
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# math score
# 67            male        group A                 high school      standard
# 40          female        group D            some high school  free/reduced
# 59            male        group E                some college  free/reduced
# 77            male        group B                 high school      standard
# 78            male        group E          associate's degree      standard
# ...            ...            ...                         ...           ...
# 73            male        group C                 high school      standard
# 85            male        group D          associate's degree  free/reduced
# 32          female        group C            some high school  free/reduced
# 73          female        group C                some college      standard
# 65            male        group A                some college      standard
#
# ...

# %%
dataset.sort_values('math score',ascending=True)
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# math score
# 13          female        group C                some college  free/reduced
# 13          female        group D                some college  free/reduced
# 23          female        group C          associate's degree  free/reduced
# 25          female        group B            some high school  free/reduced
# 26          female        group B            some high school  free/reduced
# ...            ...            ...                         ...           ...
# 100         female        group D             master's degree      standard
# 100           male        group E          associate's degree      standard
# 100           male        group E          associate's degree      standard
# 100           male        group C          associate's degree      standard
# 100           male        group D           bachelor's degree      standard
#
# ...

# %%
dataset.sort_values(['math score','writing score'],ascending=[True,False])
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# math score
# 13          female        group D                some college  free/reduced
# 13          female        group C                some college  free/reduced
# 23          female        group C          associate's degree  free/reduced
# 25          female        group B            some high school  free/reduced
# 26          female        group C                some college  free/reduced
# ...            ...            ...                         ...           ...
# 100           male        group E                 high school      standard
# 100           male        group E                some college      standard
# 100           male        group E          associate's degree      standard
# 100           male        group E           bachelor's degree      standard
# 100           male        group E                 high school      standard
#
# ...

# %%
dataset['rank']=dataset['reading score'].rank()

# %%
dataset.sort_values('rank')
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# math score
# 36            male        group C                some college  free/reduced
# 37            male        group B                 high school  free/reduced
# 43            male        group B                some college  free/reduced
# 13          female        group C                some college  free/reduced
# 31          female        group B                some college  free/reduced
# ...            ...            ...                         ...           ...
# 94          female        group A             master's degree      standard
# 85          female        group D            some high school      standard
# 84          female        group E             master's degree  free/reduced
# 92          female        group C            some high school      standard
# 85          female        group C             master's degree      standard
#
# ...

# %%
dataset.dropna()
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# math score
# 67            male        group A                 high school      standard
# 40          female        group D            some high school  free/reduced
# 59            male        group E                some college  free/reduced
# 77            male        group B                 high school      standard
# 78            male        group E          associate's degree      standard
# ...            ...            ...                         ...           ...
# 73            male        group C                 high school      standard
# 85            male        group D          associate's degree  free/reduced
# 32          female        group C            some high school  free/reduced
# 73          female        group C                some college      standard
# 65            male        group A                some college      standard
#
# ...

# %%
dataset.dropna(how='all')
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# math score
# 67            male        group A                 high school      standard
# 40          female        group D            some high school  free/reduced
# 59            male        group E                some college  free/reduced
# 77            male        group B                 high school      standard
# 78            male        group E          associate's degree      standard
# ...            ...            ...                         ...           ...
# 73            male        group C                 high school      standard
# 85            male        group D          associate's degree  free/reduced
# 32          female        group C            some high school  free/reduced
# 73          female        group C                some college      standard
# 65            male        group A                some college      standard
#
# ...

# %%
dataset.dropna(how='all',subset=['gender','lunch'])
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# math score
# 67            male        group A                 high school      standard
# 40          female        group D            some high school  free/reduced
# 59            male        group E                some college  free/reduced
# 77            male        group B                 high school      standard
# 78            male        group E          associate's degree      standard
# ...            ...            ...                         ...           ...
# 73            male        group C                 high school      standard
# 85            male        group D          associate's degree  free/reduced
# 32          female        group C            some high school  free/reduced
# 73          female        group C                some college      standard
# 65            male        group A                some college      standard
#
# ...

# %%
dataset.replace('None',np.nan)
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# math score
# 67            male        group A                 high school      standard
# 40          female        group D            some high school  free/reduced
# 59            male        group E                some college  free/reduced
# 77            male        group B                 high school      standard
# 78            male        group E          associate's degree      standard
# ...            ...            ...                         ...           ...
# 73            male        group C                 high school      standard
# 85            male        group D          associate's degree  free/reduced
# 32          female        group C            some high school  free/reduced
# 73          female        group C                some college      standard
# 65            male        group A                some college      standard
#
# ...

# %%
dataset.replace('male','man')
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# math score
# 67             man        group A                 high school      standard
# 40          female        group D            some high school  free/reduced
# 59             man        group E                some college  free/reduced
# 77             man        group B                 high school      standard
# 78             man        group E          associate's degree      standard
# ...            ...            ...                         ...           ...
# 73             man        group C                 high school      standard
# 85             man        group D          associate's degree  free/reduced
# 32          female        group C            some high school  free/reduced
# 73          female        group C                some college      standard
# 65             man        group A                some college      standard
#
# ...

# %%
dataset.isna()
# Out:
#             gender  race/ethnicity  parental level of education  lunch  \
# math score
# 67           False           False                        False  False
# 40           False           False                        False  False
# 59           False           False                        False  False
# 77           False           False                        False  False
# 78           False           False                        False  False
# ...            ...             ...                          ...    ...
# 73           False           False                        False  False
# 85           False           False                        False  False
# 32           False           False                        False  False
# 73           False           False                        False  False
# 65           False           False                        False  False
#
#             test preparation course  reading score  writing score   rank
# math score
# ...

# %%
dataset.fillna('yes')
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# math score
# 67            male        group A                 high school      standard
# 40          female        group D            some high school  free/reduced
# 59            male        group E                some college  free/reduced
# 77            male        group B                 high school      standard
# 78            male        group E          associate's degree      standard
# ...            ...            ...                         ...           ...
# 73            male        group C                 high school      standard
# 85            male        group D          associate's degree  free/reduced
# 32          female        group C            some high school  free/reduced
# 73          female        group C                some college      standard
# 65            male        group A                some college      standard
#
# ...

# %%
dataset.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# reading score                    int64
# writing score                    int64
# rank                           float64
# dtype: object

# %%
dataset['gender']=dataset['gender'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [96], in <cell line: 1>()
# ----> 1 dataset['gender']=dataset['gender'].astype(float)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
dataset['rank'].mean()
# Out:
# 500.5

# %%
dataset['reading score'].mean()
# Out:
# 69.002

# %%
dataset['reading score']=dataset['reading score'].astype(float)

# %%
dataset.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# reading score                  float64
# writing score                    int64
# rank                           float64
# dtype: object

# %%
dataset['reading score'].unique()
# Out:
# array([ 67.,  59.,  60.,  78.,  73.,  77.,  88.,  56.,  42.,  83.,  87.,
#         74.,  61.,  47.,  62.,  44.,  32.,  76.,  52.,  69.,  55.,  38.,
#         45.,  68.,  89.,  54.,  79.,  41.,  65.,  81.,  75.,  70.,  46.,
#         63.,  72.,  58.,  53.,  57.,  80.,  51.,  66.,  82.,  93.,  64.,
#         91.,  43.,  71., 100.,  50.,  33.,  34.,  90.,  84.,  95.,  98.,
#         92.,  85.,  49.,  86.,  48.,  94.,  36.,  28.,  39.,  29.,  96.,
#         97.,  40.,  27.,  37.,  99.,  31.,  35.])
